# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = "https://www.nepia.com/industry-news/coronavirus-outbreak-impact-on-shipping/"
r = requests.get(url)
soup = bs(r.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" lang="en-GB" prefix="og: http://ogp.me/ns#"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Industry News: Coronavirus Outbreak – Impact on Shipping
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- CSRF Token -->
#   <meta content="a3CH4IFJZlwEZELeF3l3tFnHYRnpQntwX6CTN4jq" name="csrf-token"/>
#   <meta content="In response to the 2019-nCoV novel Coronavirus outbreak, a number of countries, ports and organisations are publishing details of the measures being put in place." name="description"/>
#   <meta content="Industry News: Coronavirus Outbreak – Impact on Shipping" property="og:title"/>
#   <meta content="" property="og:url"/>
#   <meta content="" property="og:image"/>
#   <meta content="website" property="og:type"/>
#   <meta content="In response to the 2019-nCoV novel Coronavirus outbreak, a number of countries, ports and organisations are publishing details of the measures being put in place." property="og:description"/>
#   <meta content="2021-11-05 09:00:46" property="og:published"/>
#   <meta content="2021-11-05 17:33:16" property="og:updated"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Industry News: Coronavirus Outbreak – Impact on Shipping" name="twitter:title"/>
#   <meta content="In response to the 2019-nCoV novel Coronavirus outbreak, a number of countries, ports and organisations are publishing details of the measures being put in place." name="twitter:description"/>
#   <meta content="" name="twitter:image"/>
#   <meta content="post" name="funnelback:type"/>
#   <meta content="Industry News" name="funnelback:category:category"/>
#   <meta content="Asia|China" name="funnelback:category:Region"/>
#   <meta content="Coronavirus|Crew|People|Virus, Disease &amp; Illness" name="funnelback:category:topic_tag"/>
#   <link href="https://www.nepia.com/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <!-- Place favicon.ico in the root directory -->
#   <link href="https://www.nepia.com/css/app.min.css?v=1.1.1" rel="stylesheet"/>
#   <link href="https://www.nepia.com/css/overrides.css?v=1.1.1" rel="stylesheet"/>
#   <link href="https://use.typekit.net/trg6mza.css" rel="stylesheet"/>
#   <link href="https://unpkg.com/aos@next/dist/aos.css" rel="stylesheet"/>
#   <!-- Polyfill for asynchronously loading CSS -->
#   <script>
#    !function(t){"use strict";t.loadCSS||(t.loadCSS=function(){});var e=loadCSS.relpreload={};if(e.support=function(){var e;try{e=t.document.createElement("link").relList.supports("preload")}catch(t){e=!1}return function(){return e}}(),e.bindMediaToggle=function(t){function e(){t.media=a}var a=t.media||"all";t.addEventListener?t.addEventListener("load",e):t.attachEvent&&t.attachEvent("onload",e),setTimeout(function(){t.rel="stylesheet",t.media="only x"}),setTimeout(e,3e3)},e.poly=function(){if(!e.support())for(var a=t.document.getElementsByTagName("link"),n=0;n<a.length;n++){var o=a[n];"preload"!==o.rel||"style"!==o.getAttribute("as")||o.getAttribute("data-loadcss")||(o.setAttribute("data-loadcss",!0),e.bindMediaToggle(o))}},!e.support()){e.poly();var a=t.setInterval(e.poly,500);t.addEventListener?t.addEventListener("load",function(){e.poly(),t.clearInterval(a)}):t.attachEvent&&t.attachEvent("onload",function(){e.poly(),t.clearInterval(a)})}"undefined"!=typeof exports?exports.loadCSS=loadCSS:t.loadCSS=loadCSS}("undefined"!=typeof global?global:this);
#   </script>
#   <script>
#    localStorage.setItem("myglobeview", "false");
#   </script>
#   <script>
#    localStorage.setItem("search_session", "");
#   </script>
#   <!-- check for cookie preferences before echoing scripts -->
#  </head>
#  <body class="preload" data-pdf-url="https://northpdf.roundhousedigital.co.uk/">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5XLVQ3" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div aria-hidden="false" class="n-reveal large reveal" data-animation-in="fade-in" data-overlay="false" data-reveal="" id="modal-permission">
#    <div class="n-reveal__header">
#     <p class="n-reveal__description n-heading-3">
#     </p>
#     <a aria-label="Close modal" class="n-close n-close--modal" data-close="" href="#">
#      close
#     </a>
#    </div>
#    <div class="n-reveal__content n-mynorth-feature">
#     <div class="grid-x grid-margin-x">
#      <div class="cell medium-6 large-7">
#       <a class="n-mynorth-feature__logo" href="#">
#        <picture>
#         <source srcset="https://www.nepia.com/img/logo/logo-mynorth-black.svg" type="image/svg+xml"/>
#         <img alt="North" src="https://www.nepia.com/img/logo/logo-mynorth-black.png" srcset="https://www.nepia.com/img/logo/logo-mynorth-black.png"/>
#        </picture>
#       </a>
#       <p class="n-mynorth-feature__intro">
#        Collect and reference articles, news items and features in your own personal space
#       </p>
#       <div class="n-actions">
#        <a class="n-button n-button--full-small n-button--feature n-actions__button n-actions__button--full-small" href="https://www.nepia.com/register/">
#         Register
#        </a>
#        <p class="n-actions__text">
#         <a class="n-link" href="https://www.nepia.com/mynorth/">
#          Find out more
#         </a>
#        </p>
#       </div>
#      </div>
#      <div class="cell medium-5 medium-offset-1 large-4 large-offset-1 n-reveal__secondary">
#       <form action="https://www.nepia.com/login" class="n-form-no-label n-form-condensed" method="POST">
#        <input name="_token" type="hidden" value="a3CH4IFJZlwEZELeF3l3tFnHYRnpQntwX6CTN4jq"/>
#        <legend class="n-form-on-image__legend">
#         Already registered? Log in
#        </legend>
#        <input name="previous" type="hidden" value="https://www.nepia.com/industry-news/coronavirus-outbreak-impact-on-shipping"/>
#        <input name="postpone" type="hidden" value=""/>
#        <label class="n-form-on-image__label" for="u_login_modal">
#         <span class="show-for-sr">
#          Email Address
#         </span>
#         <input autocomplete="off" class="n-form-on-image__input" id="u_login_modal" name="login" placeholder="Email address" type="text"/>
#        </label>
#        <label class="n-form-on-image__label" for="u_password_modal">
#         <span class="show-for-sr">
#          Password
#         </span>
#         <input class="n-form-on-image__input" id="u_password_modal" name="password" onfocus="this.removeAttribute('readonly');" placeholder="Password" readonly="" type="password" value=""/>
#        </label>
#        <div class="n-remember-me">
#         <div class="n-remember-me__left">
#          <input class="n-checkbox-small n-form-on-image__checkbox" id="remember_modal" name="remember" type="checkbox"/>
#          <label class="n-remember-me__label n-form-on-image__label" for="remember_modal">
#           Remember me
#          </label>
#         </div>
#         <p class="n-remember-me__right n-xsmall-text">
#          <a class="n-remember-me__forgot n-link" href="https://www.nepia.com/password/reset">
#           Forgot your password?
#          </a>
#         </p>
#        </div>
#        <button class="n-button n-button">
#         Login
#        </button>
#       </form>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="false" class="n-reveal medium reveal" data-animation-in="fade-in" data-overlay="false" data-reveal="" id="modal-basic">
#    <a aria-label="Close modal" class="n-close n-close--modal" data-close="" href="#">
#     close
#    </a>
#    <div class="n-reveal__content n-mynorth-feature">
#     <div class="grid-x grid-margin-x">
#      <div class="cell">
#       <p class="n-mynorth-feature__intro n-reveal__description">
#       </p>
#       <div class="n-actions">
#        <a class="n-button n-button--full-small n-button--feature n-actions__button n-actions__button--full-small js-modal-confirm" href="#">
#         OK
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- The Modal -->
#   <div class="n-language-modal">
#    <!-- Modal content -->
#    <div class="n-language-modal__content" data-lang="en">
#     <span class="n-language-modal__close">
#     </span>
#     <p>
#      By selecting
#      <img alt="UK flag" src="https://www.nepia.com/img/flags/flag-en-gb.jpg"/>
#      , you have now set your site language to English. If you'd like to change your language preference again, simply click on one of the other flags.
#     </p>
#     <form action="#">
#      <input class="n-checkbox-small n-form-on-image__checkbox" id="n-language-modal__en" name="remember" type="checkbox"/>
#      <label class="" for="n-language-modal__en">
#       Do not show again
#      </label>
#     </form>
#     <a class="n-button n-button--clear" href="#" target="">
#      Close
#     </a>
#    </div>
#    <div class="n-language-modal__content n-language-modal__dual-content" data-lang="ja">
#     <span class="n-language-modal__close">
#     </span>
#     <div class="n-language-modal__content-wrapper">
#      <div>
#       <p>
#        こちら
#        <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/>
#        を選択して頂くと、言語設定が日本語に切り替わります。設定変更後は以下の機能が利用可能です。
#       </p>
#       <ul>
#        <li>
#         <p>
#          日本語版ウェブサイトへのクイックアクセスが可能となり、日本語の刊行物をご覧頂けます。
#         </p>
#        </li>
#        <li>
#         <p>
#          日本語版が閲覧可能な刊行物や記事については、日本語が優先表示されます。表示言語については
#          <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/>
#          をご参照下さい。
#         </p>
#        </li>
#       </ul>
#       <form action="#">
#        <input class="n-checkbox-small n-form-on-image__checkbox" id="n-language-modal__ja-en" name="remember" type="checkbox"/>
#        <label class="" for="n-language-modal__ja-en">
#         今後このメッセージを表示しない
#        </label>
#       </form>
#       <a class="n-button n-button--clear" href="#" target="">
#        閉じる
#       </a>
#       <span class="n-language-modal__disclaimer">
#        言語設定を切り替えたい場合には、国旗のマークをクリックして下さい。
#       </span>
#      </div>
#      <span class="n-language-modal__vertical-divider">
#      </span>
#      <div>
#       <p>
#        By selecting
#        <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/>
#        , you have now set your language to Japanese. This has several benefits, including:
#       </p>
#       <ul>
#        <li>
#         <p>
#          Providing quick access to our Japan page, which collates all our Japanese content in one place.
#         </p>
#        </li>
#        <li>
#         <p>
#          Ensures that content is presented to you in Japanese first, if we have an article, publication or webpage available in Japanese. Look out for the
#          <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/>
#          indicators across the site.
#         </p>
#        </li>
#       </ul>
#       <form action="#">
#        <input class="n-checkbox-small n-form-on-image__checkbox" id="n-language-modal__ja" name="remember" type="checkbox"/>
#        <label class="" for="n-language-modal__ja">
#         Do not show again.
#        </label>
#       </form>
#       <a class="n-button n-button--clear" href="#" target="">
#        Close
#       </a>
#       <span class="n-language-modal__disclaimer">
#        If you’d like to change your language preferences again, simply click on one of the other flags.
#       </span>
#      </div>
#     </div>
#    </div>
#    <div class="n-language-modal__content n-language-modal__dual-content" data-lang="zh-hans">
#     <span class="n-language-modal__close">
#     </span>
#     <div class="n-language-modal__content-wrapper">
#      <div>
#       <p>
#        点击选择
#        <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>
#        ，可将网站语言设置为中文。这能帮助您：
#       </p>
#       <ul>
#        <li>
#         <p>
#          快速访问我们的中国区页面，该页面将有网站内容的中文汇总。
#         </p>
#        </li>
#        <li>
#         <p>
#          在我们的文章、出版物或者网页有中文版本提供的情况下，确保首先向您展示的是中文版本的内容。您可关注站点上的
#          <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>
#          按键。
#         </p>
#        </li>
#       </ul>
#       <form action="#">
#        <input class="n-checkbox-small n-form-on-image__checkbox" id="n-language-modal__zh-hans-en" name="remember" type="checkbox"/>
#        <label class="" for="n-language-modal__zh-hans-en">
#         不再显示
#        </label>
#       </form>
#       <a class="n-button n-button--clear" href="#" target="">
#        关闭
#       </a>
#       <span class="n-language-modal__disclaimer">
#        点击任意其他国旗，可切换您的语言偏好。
#       </span>
#      </div>
#      <span class="n-language-modal__vertical-divider">
#      </span>
#      <div>
#       <p>
#        By selecting
#        <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>
#        , you have now set your language to Chinese. This has several benefits, including:
#       </p>
#       <ul>
#        <li>
#         <p>
#          Providing quick access to our China page, which collates all our Chinese content in one place.
#         </p>
#        </li>
#        <li>
#         <p>
#          Ensures that content is presented to you in Chinese first, if we have an article, publication or webpage available in Chinese. Look out for the
#          <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>
#          indicators across the site.
#         </p>
#        </li>
#       </ul>
#       <form action="#">
#        <input class="n-checkbox-small n-form-on-image__checkbox" id="n-language-modal__zh-hans" name="remember" type="checkbox"/>
#        <label class="" for="n-language-modal__zh-hans">
#         Do not show again.
#        </label>
#       </form>
#       <a class="n-button n-button--clear" href="#" target="">
#        Close
#       </a>
#       <span class="n-language-modal__disclaimer">
#        If you’d like to change your language preferences again, simply click on one of the other flags.
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <header class="n-banner">
#    <div class="n-banner__logo-breadcrumbs">
#     <div class="inner">
#      <a class="n-logo-link" href="https://www.nepia.com">
#       <picture class="n-logo n-logo--black">
#        <source srcset="https://www.nepia.com/img/logo/logo-black.svg" type="image/svg+xml"/>
#        <img alt="North" src="https://www.nepia.com/img/logo/logo-black.png" srcset="https://www.nepia.com/img/logo/logo-black.png"/>
#       </picture>
#       <picture class="n-logo n-logo--white">
#        <source srcset="https://www.nepia.com/img/logo/logo-white.svg" type="image/svg+xml"/>
#        <img alt="North" src="https://www.nepia.com/img/logo/logo-white.png" srcset="https://www.nepia.com/img/logo/logo-white.png"/>
#       </picture>
#       <picture class="n-logo n-logo--strap-white">
#        <source srcset="https://www.nepia.com/img/logo/logo-white-strap.svg" type="image/svg+xml"/>
#        <img alt="North" src="https://www.nepia.com/img/logo/logo-white-strap.png" srcset="https://www.nepia.com/img/logo/logo-white-strap.png"/>
#       </picture>
#      </a>
#      <nav aria-label="You are here:" class="n-breadcrumbs" role="navigation">
#       <ul class="n-breadcrumbs__list">
#        <li class="n-breadcrumbs__item">
#         <a href="https://www.nepia.com/">
#          Home
#         </a>
#        </li>
#        <li class="n-breadcrumbs__item">
#         <a href="https://www.nepia.com/latest/industry-news/">
#          Industry News
#         </a>
#        </li>
#        <li class="n-breadcrumbs__item">
#         <span class="show-for-sr">
#          Current:
#         </span>
#         COVID-19: Coronavirus Outbreak – Impact on Shipping *Update*
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <div class="n-site-navigation">
#     <div class="n-site-navigation__inner inner">
#      <div class="n-toggle-language">
#       <ul class="n-toggle-language__list n-language-list">
#        <li class="n-language-list__item">
#         <a class="n-language-list__link" data-lang="ja" href="/japan">
#          <img alt="Japan flag" class="n-language-list__image n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/>
#         </a>
#        </li>
#        <li class="n-language-list__item">
#         <a class="n-language-list__link" data-lang="zh-hans" href="/china">
#          <img alt="China flag" class="n-language-list__image" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>
#         </a>
#        </li>
#        <li class="n-language-list__item is-active">
#         <a class="n-language-list__link" data-lang="en" href="/">
#          <img alt="UK flag" class="n-language-list__image" src="https://www.nepia.com/img/flags/flag-en-gb.jpg"/>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="n-site-navigation__toggles">
#       <div class="n-emergency-contact-mini">
#        <p class="n-emergency-contact-mini__text">
#         <span class="n-emergency-contact-mini__description">
#          Office Hours Emergencies
#         </span>
#         <a class="n-emergency-contact-mini__tel" href="tel: +44 191 232 5221">
#          +44 191 232 5221
#         </a>
#        </p>
#       </div>
#       <a class="n-toggle-nav-primary" href="#nav-primary">
#        Toggle navigation
#       </a>
#       <a class="n-toggle-contact" href="/contact">
#        Contact Us
#       </a>
#       <a class="n-toggle-search js-toggle-search" href="javascript:void(0);">
#        Toggle search
#       </a>
#      </div>
#      <div class="n-site-search">
#       <div class="n-site-search__header">
#        <div class="n-site-search__inner inner">
#         <form action="https://www.nepia.com/search" class="n-site-search__form">
#          <span class="n-site-search__title">
#           Search North
#          </span>
#          <input autocomplete="off" class="n-site-search__input" name="q" placeholder="How can we help you?" type="text"/>
#          <button class="n-site-search__button">
#           Submit
#          </button>
#         </form>
#         <a class="n-site-search__close js-toggle-search" href="javascript:void(0);">
#          <span>
#           Close
#          </span>
#         </a>
#         <div class="n-site-search__suggestions">
#          <h2 class="n-heading-5">
#           Suggestions
#          </h2>
#          <ul class="n-list-large n-list-large--white-xlarge n-list-col-2">
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/latest/publications/newsletters/signals-124-summer-2021/">
#             Signals 124 - Summer 2021
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/about-us/who-we-are/financial-strength/annual-review/annual-review-2021/">
#             Annual Review 2021
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/latest/all-publications/rule-books-and-recommended-clauses/">
#             2021/22 Rule Books
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/topics/covid-19-coronavirus/">
#             Coronavirus Outbreak
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/myglobeview/">
#             Route Risk Advice
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/myglobeview/">
#             MyGlobeView
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/topics/sanctions/">
#             Sanctions Updates
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/latest/publications/">
#             Latest Publications
#            </a>
#           </li>
#           <li class="n-list-large__item">
#            <a class="n-list-large__link" href="https://www.nepia.com/latest/news/">
#             Latest News &amp; Updates
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="n-site-search__live">
#        <div class="n-site-search__inner n-site-search__inner--border inner">
#         <h2 class="show-for-sr">
#          Results
#         </h2>
#         <div class="grid-x grid-margin-x medium-up-3 large-up-4">
#          <div class="n-site-search__category cell hide">
#           <div class="n-category-tag n-category-tag--title">
#            <ul class="n-category-tag__list">
#             <li class="n-category-tag__item">
#              <a class="n-category-tag__type" href="#">
#               Areas of Expertise
#              </a>
#             </li>
#            </ul>
#           </div>
#           <ul class="n-card-list n-card-list--on-image-xlarge" id="js-search-suggest-topic">
#            <li class="n-card-list__item hide" id="js-template-suggestion-topic">
#             <article class="n-card n-card--on-image-xlarge">
#              <a class="n-card__link" href="#">
#               <h3 class="n-card__title n-card__title--large">
#               </h3>
#              </a>
#             </article>
#            </li>
#           </ul>
#           <a class="n-button n-button--clear n-button--white-xlarge n-button--bottom js-generate-search-term" href="https://www.nepia.com/search?q=&amp;type=f.Content+Type%7Cnorth-topics=Expertise">
#            View all area of expertise
#           </a>
#          </div>
#          <div class="n-site-search__category cell hide">
#           <div class="n-category-tag n-category-tag--title">
#            <ul class="n-category-tag__list">
#             <li class="n-category-tag__item">
#              <a class="n-category-tag__type" href="#">
#               Publications
#              </a>
#             </li>
#            </ul>
#           </div>
#           <ul class="n-card-list n-card-list--on-image-xlarge" id="js-search-suggest-publication">
#            <li class="n-card-list__item hide" id="js-template-suggestion-publication">
#             <article class="n-card n-card--on-image-xlarge">
#              <a class="n-card__link" href="#">
#               <time class="n-card__time n-time" datetime="">
#               </time>
#               <h3 class="n-card__title n-card__title--large">
#               </h3>
#              </a>
#             </article>
#            </li>
#           </ul>
#           <a class="n-button n-button--clear n-button--white-xlarge n-button--bottom js-generate-search-term" href="https://www.nepia.com/search?q=&amp;type=f.Content+Type%7Cnorth-publications=Publications">
#            View all publications
#           </a>
#          </div>
#          <div class="n-site-search__category cell hide">
#           <div class="n-category-tag n-category-tag--title">
#            <ul class="n-category-tag__list">
#             <li class="n-category-tag__item">
#              <a class="n-category-tag__type" href="#">
#               News
#              </a>
#             </li>
#            </ul>
#           </div>
#           <ul class="n-card-list n-card-list--on-image-xlarge" id="js-search-suggest-post">
#            <li class="n-card-list__item hide" id="js-template-suggestion-post">
#             <article class="n-card n-card--on-image-xlarge">
#              <a class="n-card__link" href="#">
#               <time class="n-card__time n-time" datetime="">
#               </time>
#               <h3 class="n-card__title n-card__title--large">
#               </h3>
#              </a>
#              <div class="n-category-tag n-category-tag--bottom">
#               <ul class="n-category-tag__list">
#                <li class="n-category-tag__item hide">
#                 <a class="n-category-tag__type" href="#">
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </article>
#            </li>
#           </ul>
#           <a class="n-button n-button--clear n-button--white-xlarge n-button--bottom js-generate-search-term" href="https://www.nepia.com/search?q=&amp;type=f.Content+Type%7CFUN3olbwj209ffngoor6oumzueqk=News">
#            View all news
#           </a>
#          </div>
#          <div class="n-site-search__category cell hide">
#           <div class="n-category-tag n-category-tag--title">
#            <ul class="n-category-tag__list">
#             <li class="n-category-tag__item">
#              <a class="n-category-tag__type" href="#">
#               Circulars
#              </a>
#             </li>
#            </ul>
#           </div>
#           <ul class="n-card-list n-card-list--on-image-xlarge" id="js-search-suggest-circular">
#            <li class="n-card-list__item hide" id="js-template-suggestion-circular">
#             <article class="n-card n-card--on-image-xlarge">
#              <a class="n-card__link" href="#">
#               <time class="n-card__time n-time" datetime="">
#               </time>
#               <h3 class="n-card__title n-card__title--large">
#               </h3>
#              </a>
#              <div class="n-category-tag n-category-tag--bottom">
#               <ul class="n-category-tag__list">
#                <li class="n-category-tag__item hide">
#                 <a class="n-category-tag__type" href="#">
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </article>
#            </li>
#           </ul>
#           <a class="n-button n-button--clear n-button--white-xlarge n-button--bottom js-generate-search-term" href="https://www.nepia.com/search?q=&amp;type=f.Content+Type%7CFUNcvkvlvzeu7617os2c8yqtomle=Circulars">
#            View all circulars
#           </a>
#          </div>
#          <div class="n-site-search__category cell hide">
#           <div class="n-category-tag n-category-tag--title">
#            <ul class="n-category-tag__list">
#             <li class="n-category-tag__item">
#              <a class="n-category-tag__type" href="#">
#               People
#              </a>
#             </li>
#            </ul>
#           </div>
#           <ul class="grid-x grid-margin-x small-up-2 medium-up-1 n-staff-list" id="js-search-suggest-staff">
#            <li class="cell n-staff-list__item hide" id="js-template-suggestion-staff">
#             <article class="n-staff-card n-staff-card--on-image-xlarge">
#              <a class="n-staff-card__link" href="#">
#               <img alt="" class="n-staff-card__image n-staff-card__image--small" src="https://www.nepia.com/img/content/staff-thumb-large-no-image.jpg"/>
#               <div class="n-staff-card__content">
#                <h3 class="n-staff-card__name">
#                </h3>
#                <p class="n-staff-card__job-title">
#                </p>
#               </div>
#              </a>
#             </article>
#            </li>
#           </ul>
#           <a class="n-button n-button--clear n-button--white-xlarge n-button--bottom js-generate-search-term" href="https://www.nepia.com/search?q=&amp;type=f.Content+Type%7Cnorth-staff=Contacts">
#            View all people
#           </a>
#          </div>
#          <div class="n-site-search__category cell hide">
#           <div class="n-category-tag n-category-tag--title">
#            <ul class="n-category-tag__list">
#             <li class="n-category-tag__item">
#              <a class="n-category-tag__type" href="#">
#               Correspondents
#              </a>
#             </li>
#            </ul>
#           </div>
#           <ul class="n-card-list n-card-list--on-image-xlarge" id="js-search-suggest-correspondent">
#            <li class="n-card-list__item hide" id="js-template-suggestion-correspondent">
#             <article class="n-card n-card--on-image-xlarge">
#              <a class="n-card__link" href="#">
#               <h3 class="n-card__title n-card__title--large">
#               </h3>
#               <ul class="n-card__details">
#                <li>
#                 <strong class="js-port">
#                 </strong>
#                </li>
#                <li>
#                 <strong class="js-country">
#                 </strong>
#                </li>
#               </ul>
#              </a>
#             </article>
#            </li>
#           </ul>
#           <a class="n-button n-button--clear n-button--white-xlarge n-button--bottom js-generate-search-term" href="https://www.nepia.com/search?q=&amp;type=f.Content+Type%7Cnorth-correspondents=Correspondents">
#            View all correspondents
#           </a>
#          </div>
#          <div class="n-site-search__category cell hide">
#           <div class="n-category-tag n-category-tag--title">
#            <ul class="n-category-tag__list">
#             <li class="n-category-tag__item">
#              <a class="n-category-tag__type" href="#">
#               Further content
#              </a>
#             </li>
#            </ul>
#           </div>
#           <ul class="n-card-list n-card-list--on-image-xlarge" id="js-search-suggest-page">
#            <li class="n-card-list__item hide" id="js-template-suggestion-page">
#             <article class="n-card n-card--on-image-xlarge">
#              <a class="n-card__link" href="#">
#               <h3 class="n-card__title n-card__title--large">
#               </h3>
#              </a>
#             </article>
#            </li>
#           </ul>
#           <a class="n-button n-button--clear n-button--white-xlarge n-button--bottom js-generate-search-term" href="https://www.nepia.com/search?q=&amp;type=f.Content+Type%7Cnorth-pages=Further+Content">
#            View all further content
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <nav class="n-nav-primary">
#       <div class="n-nav-primary__header">
#        <a class="n-nav-primary__section" href="#">
#         About North
#        </a>
#        <a class="n-nav-primary__back n-link-back" href="#">
#         <span class="n-link-back__text">
#          Back
#         </span>
#        </a>
#       </div>
#       <ul class="n-nav-list menu">
#        <li class="n-nav-list__item n-nav-home-link">
#         <a class="n-nav-list__link" href="https://www.nepia.com">
#          <img alt="North" src="https://www.nepia.com/img/logo/logo-black.svg"/>
#         </a>
#        </li>
#        <li class="n-nav-list__item menu-item-has-children">
#         <a class="n-nav-list__link" href=" https://www.nepia.com/mynorth/ ">
#          <span class="n-nav-list__text">
#           MyNorth
#          </span>
#         </a>
#         <span class="n-button-move">
#         </span>
#         <div class="n-nav-sub-menu">
#          <div class="n-nav-sub-menu__inner inner">
#           <div class="grid-x grid-margin-x">
#            <div class="cell medium-6 xlarge-5">
#             <div class="n-nav-sub-menu__header n-nav-sub-menu__header--visible">
#              <h1 class="n-nav-sub-menu__title n-nav-sub-menu__title--image">
#               <span class="show-for-sr">
#                MyNorth
#               </span>
#               <picture>
#                <source srcset="https://www.nepia.com/img/logo/logo-mynorth-black.svg" type="image/svg+xml"/>
#                <img alt="North" src="https://www.nepia.com/img/logo/logo-mynorth-black.png" srcset="https://www.nepia.com/img/logo/logo-mynorth-black.png"/>
#               </picture>
#              </h1>
#              <p class="n-nav-sub-menu__text n-nav-sub-menu__text--large n-text-no-margin">
#               Collect and reference articles, news items and contacts in your own personal space...
#              </p>
#              <div class="n-actions">
#               <a class="n-button n-button--full-small n-button--feature n-actions__button n-actions__button--full-small" href="https://www.nepia.com/register/">
#                Register
#               </a>
#               <p class="n-actions__text">
#                <a class="n-link" href="https://www.nepia.com/mynorth/">
#                 Find out more about MyNorth
#                </a>
#               </p>
#              </div>
#             </div>
#            </div>
#            <div class="n-nav-cols cell medium-6 xlarge-7">
#             <div class="n-nav-cols__primary">
#              <form action="https://www.nepia.com/login" class="n-form-no-label n-form-condensed" method="POST">
#               <input name="_token" type="hidden" value="a3CH4IFJZlwEZELeF3l3tFnHYRnpQntwX6CTN4jq"/>
#               <legend class="n-form-on-image__legend">
#                Login
#               </legend>
#               <input name="previous" type="hidden" value="https://www.nepia.com/industry-news/coronavirus-outbreak-impact-on-shipping"/>
#               <input name="postpone" type="hidden" value=""/>
#               <label class="n-form-on-image__label" for="u_login_header">
#                <span class="show-for-sr">
#                 Email Address
#                </span>
#                <input autocomplete="off" class="n-form-on-image__input" id="u_login_header" name="login" placeholder="Email address" type="text"/>
#               </label>
#               <label class="n-form-on-image__label" for="u_password_header">
#                <span class="show-for-sr">
#                 Password
#                </span>
#                <input class="n-form-on-image__input" id="u_password_header" name="password" onfocus="this.removeAttribute('readonly');" placeholder="Password" readonly="" type="password" value=""/>
#               </label>
#               <div class="n-remember-me">
#                <div class="n-remember-me__left">
#                 <input class="n-checkbox-small n-form-on-image__checkbox" id="remember_header" name="remember" type="checkbox"/>
#                 <label class="n-remember-me__label n-form-on-image__label" for="remember_header">
#                  Remember me
#                 </label>
#                </div>
#                <p class="n-remember-me__right n-xsmall-text">
#                 <a class="n-remember-me__forgot n-link" href="https://www.nepia.com/password/reset">
#                  Forgot your password?
#                 </a>
#                </p>
#               </div>
#               <button class="n-button">
#                Login
#               </button>
#              </form>
#             </div>
#             <div class="n-nav-cols__secondary">
#              <h2 class="n-replace-text n-nav-cols__image-title">
#               <span class="show-for-sr">
#                NorthOnline
#               </span>
#               <picture>
#                <source srcset="https://www.nepia.com/img/logo/logo-northonline-black.png" type="image/svg+xml"/>
#                <img alt="North Online" src="https://www.nepia.com/img/logo/logo-northonline-black.png" srcset="https://www.nepia.com/img/logo/logo-northonline-black.png"/>
#               </picture>
#              </h2>
#              <p class="n-heading-3">
#               Access confidential risk and vessel data with NorthOnline
#              </p>
#              <a class="n-button n-north-online-description-cta" href="https://members.nepia.com/" target="_blank">
#               Login
#              </a>
#              <p class="n-north-online-description">
#               NorthOnline is a separate area to MyNorth and requires different login credentials. If you have forgotten your password or require access to NorthOnline, please email
#               <a href="mailto:northonline.access@nepia.com">
#                northonline.access@nepia.com.
#               </a>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="n-nav-list__item menu-item-has-children">
#         <a class="n-nav-list__link" href=" https://globeview.nepia.com?c=main-menu-globeview ">
#          <span class="n-nav-list__text">
#           GlobeView
#          </span>
#         </a>
#         <span class="n-button-move">
#         </span>
#         <div class="n-nav-sub-menu">
#          <div class="n-nav-sub-menu__inner inner">
#           <div class="grid-x grid-margin-x">
#            <div class="cell xlarge-5">
#             <div class="n-nav-sub-menu__header">
#              <h1 class="n-nav-sub-menu__title">
#               Intelligence Platforms
#              </h1>
#              <p class="n-nav-sub-menu__text">
#               Our maritime intelligence platforms have been designed to assist you in your shipping operations. From planning a voyage, to assessing the latest Covid-19 developments, our platforms contain a wide range of regularly updated data feeds to allow you to properly manage your risks.
#              </p>
#              <a class="n-nav-sub-menu__link" href="https://nepia.com/myglobeview">
#               Find out more
#              </a>
#             </div>
#            </div>
#            <div class="cell xlarge-7">
#             <ul class="n-nav-list-level-2" style="min-height: 0px;">
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://globeview.nepia.com?c=main-menu-drop-globeview">
#                GlobeView
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://nepia.com/members-area/globeview?c=main-menu-drop-my-globeview">
#                MyGlobeView
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://nepia.com/members-area/routeriskadvice/app?c=main-menu-drop-rra">
#                Route Risk Advice
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://nepia.com/members-area/globeview/support?c=main-menu-drop-support-feedback">
#                Support and feedback
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="n-nav-list__item">
#         <a class="n-nav-list__link" href="https://www.nepia.com/vessel-search/">
#          <span class="n-nav-list__text">
#           Vessel Search
#          </span>
#         </a>
#         <span class="n-button-move">
#         </span>
#        </li>
#        <li class="n-nav-list__item menu-item-has-children">
#         <a class="n-nav-list__link" href="https://www.nepia.com/correspondents/">
#          <span class="n-nav-list__text">
#           Correspondents
#          </span>
#         </a>
#         <span class="n-button-move">
#         </span>
#         <div class="n-nav-sub-menu">
#          <div class="n-nav-sub-menu__inner inner">
#           <div class="grid-x grid-margin-x">
#            <div class="cell xlarge-5">
#             <div class="n-nav-sub-menu__header">
#              <h1 class="n-nav-sub-menu__title">
#               Correspondents
#              </h1>
#              <p class="n-nav-sub-menu__text">
#               Our comprehensive network of correspondents are based in all the major ports and maritime centres around the globe.
#              </p>
#             </div>
#            </div>
#            <div class="cell xlarge-7">
#             <ul class="n-nav-list-level-2">
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/correspondents/">
#                Our Correspondents
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/first-call/">
#                First Call
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="n-nav-list__item menu-item-has-children">
#         <a class="n-nav-list__link" href="https://www.nepia.com/latest/updates/">
#          <span class="n-nav-list__text">
#           Latest
#          </span>
#         </a>
#         <span class="n-button-move">
#         </span>
#         <div class="n-nav-sub-menu">
#          <div class="n-nav-sub-menu__inner inner">
#           <div class="grid-x grid-margin-x">
#            <div class="cell xlarge-5">
#             <div class="n-nav-sub-menu__header">
#              <h1 class="n-nav-sub-menu__title">
#               Latest
#              </h1>
#              <p class="n-nav-sub-menu__text">
#               From news and articles to circulars and publications, keep across the latest industry updates that are relevant to you.
#              </p>
#             </div>
#            </div>
#            <div class="cell xlarge-7">
#             <ul class="n-nav-list-level-2">
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/latest/updates/">
#                Updates
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/latest/circulars/">
#                Circulars
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#              <li class="n-nav-list-level-2__item menu-item-has-children">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/latest/news">
#                Latest News
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#               <div class="n-nav-sub-menu-last">
#                <ul class="n-nav-list-level-3">
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/news/">
#                   Latest News
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/circulars/">
#                   Circulars
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/articles/">
#                   Articles
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/our-news/press-hub/">
#                   Press Hub
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/industry-news/">
#                   Industry News
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/our-news/">
#                   Our News
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li class="n-nav-list-level-2__item menu-item-has-children">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/latest/publications/">
#                Publications
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#               <div class="n-nav-sub-menu-last">
#                <ul class="n-nav-list-level-3">
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/all-publications/">
#                   All Publications
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/publications/">
#                   Topics
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/about-us/who-we-are/financial-strength/">
#                   Financial Strength
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/all-publications/rule-books-and-recommended-clauses/">
#                   Rule Books and Recommended Clauses
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/publications/club-information/">
#                   Club Information
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/publications/newsletters/">
#                   Newsletters
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/latest/publications/international-group/">
#                   International Group
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="n-nav-list__item menu-item-has-children">
#         <a class="n-nav-list__link" href="https://www.nepia.com/about-us/who-we-are/about-north/">
#          <span class="n-nav-list__text">
#           About North
#          </span>
#         </a>
#         <span class="n-button-move">
#         </span>
#         <div class="n-nav-sub-menu">
#          <div class="n-nav-sub-menu__inner inner">
#           <div class="grid-x grid-margin-x">
#            <div class="cell xlarge-5">
#             <div class="n-nav-sub-menu__header">
#              <h1 class="n-nav-sub-menu__title">
#               About North
#              </h1>
#              <p class="n-nav-sub-menu__text">
#               North is a leading global marine insurer with over 160 years of history in the industry. Our purpose today remains as it was on our inception in 1860; to enable our Members to trade with confidence.
#              </p>
#              <a class="n-nav-sub-menu__link" href="https://www.nepia.com/about-us/who-we-are/about-north/">
#               Find out more
#              </a>
#             </div>
#            </div>
#            <div class="cell xlarge-7">
#             <ul class="n-nav-list-level-2">
#              <li class="n-nav-list-level-2__item">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/about-us/our-people/">
#                Our People
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#              </li>
#              <li class="n-nav-list-level-2__item menu-item-has-children">
#               <a class="n-nav-list-level-2__link" href="https://www.nepia.com/about-us/who-we-are/">
#                Who We Are
#               </a>
#               <span class="n-button-move n-button-move--smaller">
#               </span>
#               <div class="n-nav-sub-menu-last">
#                <ul class="n-nav-list-level-3">
#                 <li class="n-nav-list-level-3__item">
#                  <a class="n-nav-list-level-3__link" href="https://www.nepia.com/about-us/who-we-are/about-north/">
#                   About Us
#                  </a>
#                 </li>
#                 <li class="n-nav-list-level-3__item">
# ...
#                Industry News
#               </a>
#              </li>
#             </ul>
#            </div>
#           </article>
#          </li>
#          <li class="n-card-list__item">
#           <article class="n-card">
#            <a class="n-card__link" href="https://www.nepia.com/our-news/coronavirus-norths-offices-working-arrangements/">
#             <h3 class="n-card__title n-card__title--small">
#              Coronavirus - North's Offices Working Arrangements
#             </h3>
#            </a>
#            <div class="n-category-tag n-category-tag--bottom">
#             <ul class="n-category-tag__list">
#              <li class="n-category-tag__item">
#               <a class="n-category-tag__type" href="#">
#                Our News
#               </a>
#              </li>
#             </ul>
#            </div>
#           </article>
#          </li>
#          <li class="n-card-list__item">
#           <article class="n-card">
#            <a class="n-card__link" href="https://www.nepia.com/articles/2021-world-maritime-day-theme-seafarers-at-the-core-of-shippings-future/">
#             <h3 class="n-card__title n-card__title--small">
#              2021 World Maritime Day Theme: Seafarers – At the Core Of Shipping’s Future
#             </h3>
#            </a>
#            <div class="n-category-tag n-category-tag--bottom">
#             <ul class="n-category-tag__list">
#              <li class="n-category-tag__item">
#               <a class="n-category-tag__type" href="#">
#                Articles
#               </a>
#              </li>
#             </ul>
#            </div>
#           </article>
#          </li>
#         </ul>
#        </aside>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="n-layout-full-width n-layout-full-width--left-aligned">
#     <div class="n-component-block n-publications-thumbnails" id="">
#      <div class="inner">
#       <h2 class="n-title-block-space">
#        Read the country advice
#       </h2>
#       <ul class="grid-x grid-margin-x n-card-list n-card-list--no-border small-up-3" data-aos="fade-up">
#        <li class="cell n-card-list__item">
#         <article class="n-card n-card--flex">
#          <a class="n-card__link" href="https://www.nepia.com/publications/covid-19-coronavirus-outbreak-impact-on-shipping/">
#           <img alt="Covid 19 - Coronavirus Impact on shipping" class="n-card__image n-card__image--shadow" src="https://north-live.s3.eu-west-2.amazonaws.com/wp-content/uploads/2020/03/15160117/Covid-19-Coronavirus-Impact-on-shipping-Thumbnail1.jpg"/>
#           <h3 class="n-card__title">
#            COVID-19: Coronavirus Outbreak – Impact on Shipping
#           </h3>
#          </a>
#          <a class="n-function-button n-function-button--add js-linked-postpone" data-modal-message="To add this to your library you need a MyNorth account" data-open="modal-permission" data-post_id="81087" data-post_title="COVID-19: Coronavirus Outbreak – Impact on Shipping" data-post_type="publications" href="#">
#           <span class="n-function-button__text">
#            Add to library
#           </span>
#          </a>
#         </article>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="n-component-block n-component-block--flush n-divider">
#      <hr class="n-divider__hr"/>
#     </div>
#     <div class="n-component-block n-component-block--close-space n-general-text" id="">
#      <div class="n-component-block__inner">
#       <div class="n-component-block__align">
#        <h2>
#         Using our online publications
#        </h2>
#        <p>
#         Our online publications are more interactive and improve searchability and speed of access. You can now read this publication directly from our website, and can simply print specific countries relevant to you. For Members, brokers and correspondents with MyNorth accounts, you can also add this publication to your library for quick access.
#        </p>
#        <h3>
#         Navigating the Publication
#        </h3>
#        <p>
#         The country advice is available down the right of the publication page. You can quickly navigate to a country by clicking the heading in the contents. If you are looking for something in particular, you can use the search at the top of the publication. When you submit a search term, it will provide an overview of the results by relevancy.
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="n-component-block n-component-block--flush n-divider">
#      <hr class="n-divider__hr"/>
#     </div>
#    </div>
#   </main>
#   <footer class="n-footer">
#    <div class="inner">
#     <div class="grid-x grid-margin-x">
#      <div class="n-footer__links-primary cell medium-4 large-5">
#       <h2 class="n-footer__title n-heading-5">
#        Expertise
#       </h2>
#       <ul class="n-link-list n-footer__col-list">
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/2020-vision/">
#          2020 Sulphur Cap
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/ballast-water-management/">
#          Ballast Water Management
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/cyber-security/">
#          Cyber Security
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/gdpr/">
#          GDPR
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/marine-environment/">
#          Marine Environment
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/mlc/">
#          MLC
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/right-crew/">
#          Right Crew
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/safety-management-2-0/">
#          Safety Management 2.0
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/topics/sanctions/">
#          Sanctions
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="n-footer__links-secondary cell medium-4 large-5">
#       <h2 class="n-footer__title n-heading-5">
#        Quick Links
#       </h2>
#       <ul class="n-link-list n-footer__col-list">
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/mynorth/">
#          MyNorth
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://globeview.nepia.com">
#          GlobeView
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/vessel-search/">
#          Vessel Search
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/correspondents/">
#          Correspondents
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/latest/">
#          Latest
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/about-us/who-we-are/about-north/">
#          About Us
#         </a>
#        </li>
#        <li class="n-link-list__item n-footer__col-item">
#         <a class="n-link-list__link" href="https://www.nepia.com/contact/">
#          Contact
#         </a>
#        </li>
#        <li class="n-link-list__item n-link-list__item--no-border n-footer__col-item">
#         <a class="show-for-sr" href=" https://www.nepia.com/mynorth/ ">
#          MyNorth
#         </a>
#         <ul class="n-list n-list--nested">
#          <li class="n-list__item n-list__item--nested">
#           <a class="n-list__link" href="https://www.nepia.com/register/">
#            Register
#           </a>
#          </li>
#          <li class="n-list__item n-list__item--nested">
#           <a class="n-list__link" href="https://www.nepia.com/login">
#            Login
#           </a>
#          </li>
#          <li class="n-list__item n-list__item--nested">
#           <a class="n-list__link" href="https://members.nepia.com/" target="_blank">
#            North Online
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#      <div class="n-footer__links-tertiary cell medium-4 large-2">
#       <h2 class="n-footer__title n-heading-5">
#        Connect
#       </h2>
#       <ul class="n-footer__connect-list n-social-list">
#        <li class="n-footer__connect-item n-social-list__item">
#         <a class="n-social-list__link n-social-list__link--linkedin" href="https://www.linkedin.com/company/the-north-of-england-p&amp;i-association-limited" target="_blank">
#          LinkedIn
#         </a>
#        </li>
#        <li class="n-footer__connect-item n-social-list__item">
#         <a class="n-social-list__link n-social-list__link--twitter" href="https://twitter.com/NorthPandIClub" target="_blank">
#          Twitter
#         </a>
#        </li>
#        <li class="n-footer__connect-item n-social-list__item">
#         <a class="n-social-list__link n-social-list__link--facebook" href="https://www.facebook.com/northpandiclub/" target="_blank">
#          Facebook
#         </a>
#        </li>
#        <li class="n-footer__connect-item n-social-list__item">
#         <a class="n-social-list__link n-social-list__link--youtube" href="https://www.youtube.com/northpiclub" target="_blank">
#          Youtube
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="n-footer__base cell">
#       <div class="n-emergency-contact">
#       </div>
#       <div class="n-footer__misc">
#        <ul class="n-footer__misc-list">
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/terms-conditions/">
#           Terms &amp; Conditions
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/privacy-policy/">
#           Privacy Policy
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/cookie-policy/">
#           Cookie Policy
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/anti-bribery-trading/">
#           Anti-Bribery &amp; Trading
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/complaints/">
#           Complaints
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/employers-liability-register/">
#           Employers’ Liability Register
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/modern-slavery-statements/">
#           Modern Slavery Statements
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/gender-pay-gap/">
#           Gender Pay Gap
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/statement-of-investment-principles/">
#           Statement of Investment Principles
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://s3-eu-west-2.amazonaws.com/north-live/wp-content/uploads/2019/09/18190617/Health-Safety-Policy.pdf">
#           Health and Safety Policy Statement of Commitment
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://s3-eu-west-2.amazonaws.com/north-live/wp-content/uploads/2020/03/11153516/BOARD-DIVERSITY-POLICY.pdf">
#           Board Diversity Policy
#          </a>
#         </li>
#         <li class="n-footer__misc-item">
#          <a class="n-footer__misc-link" href="https://www.nepia.com/about-us/careers/">
#           Careers
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="inner">
#     <div class="n-footer-logo">
#      <span>
#       <p class="n-footer-logo__title">
#        Member of
#       </p>
#       <img alt="IGP &amp; I Logo" class="n-footer-logo__logo n-footer-logo__logo-last" src="https://north-live.s3.eu-west-2.amazonaws.com/wp-content/uploads/2019/09/06170510/IGPI-logo.png"/>
#      </span>
#      <span>
#       <p class="n-footer-logo__title">
#        Accreditations
#       </p>
#       <img alt="SAFETY4SEA Technology Award 2020" class="n-footer-logo__logo" src="https://north-live.s3.eu-west-2.amazonaws.com/wp-content/uploads/2020/10/21100611/SAFETY4SEA-Technology-Award-2020-1.png"/>
#      </span>
#      <img alt="2019 SAFETY4SEA Initiative Award" class="n-footer-logo__logo n-footer-logo__logo-last" src="https://north-live.s3.eu-west-2.amazonaws.com/wp-content/uploads/2019/10/02091202/2019-SAFETY4SEA-Initiative-Award-small.png"/>
#     </div>
#    </div>
#    <div class="n-footer__regulatory_information inner">
#     <p>
#      Copyright © The North of England Protecting and Indemnity Association Limited. Registered in England. No. 505456. The Quayside, Newcastle upon Tyne, NE1 3DU Authorised by the Prudential Regulation Authority and regulated by the Financial Conduct Authority and the Prudential Regulation Authority.
#      <br/>
#      <br/>
#      North's business in the EEA is underwritten by North of England P&amp;I Designated Activity Company, a wholly owned subsidiary of North incorporated in Ireland and regulated by the Central Bank of Ireland.
#     </p>
#    </div>
#   </footer>
#   <section class="alert-banner alert-banner--hide" id="js-rhd-cookie-bar">
#    <div class="alert-banner__container">
#     <div class="alert-banner__content">
#      <h3>
#       Your cookie preferences
#      </h3>
#      <p>
#       We use necessary cookies to make our website function and to enable core functionality. You can disable these in your browser settings, however sections of our website may not work correctly.
#      </p>
#      <p>
#       We also use performance cookies to help improve our website and provide the best user experience, this includes collecting and reporting information on how you use the site.
#      </p>
#      <p>
#       To get the best online experience we recommend that you accept all cookies. For more information, or to change your settings, please select ‘manage cookies’ or visit our our
#       <a href="https://www.nepia.com/cookie-policy/">
#        Cookie Policy
#       </a>
#       page.
#      </p>
#      <div class="alert-banner__buttons">
#       <a class="rhd-btn rhd-btn--accept" href="#" id="js-rhd-cookie-accept-all">
#        Accept all cookies
#       </a>
#       <a class="rhd-btn" href="https://www.nepia.com/cookie-policy/" id="js-rhd-cookie-manage">
#        Manage cookies
#       </a>
#      </div>
#     </div>
#     <div class="alert-banner__dots js-alert-dots">
#      <span>
#      </span>
#      <span class="active">
#      </span>
#     </div>
#    </div>
#   </section>
#   <div class="body-overlay" id="js-body-overlay">
#   </div>
#   <script defer="" src="https://www.nepia.com/js/main.min.js?v=cf94db48fb7aa4da74260da3f6c7e4722e913b72" type="text/javascript">
#   </script>
#   <script defer="" src="https://www.nepia.com/js/plugins.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/zxcvbn/4.2.0/zxcvbn.js">
#   </script>
#  </body>
# </html>

# %%
print(soup.find_all('p'))
# Out:
# [<p class="n-reveal__description n-heading-3"></p>, <p class="n-mynorth-feature__intro">Collect and reference articles, news items and features in your own personal space</p>, <p class="n-actions__text"><a class="n-link" href="https://www.nepia.com/mynorth/">Find out more</a></p>, <p class="n-remember-me__right n-xsmall-text"><a class="n-remember-me__forgot n-link" href="https://www.nepia.com/password/reset">Forgot your password?</a></p>, <p class="n-mynorth-feature__intro n-reveal__description"></p>, <p>By selecting  <img alt="UK flag" src="https://www.nepia.com/img/flags/flag-en-gb.jpg"/>, you have now set your site language to English. If you'd like to change your language preference again, simply click on one of the other flags.</p>, <p>
#                     こちら <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/> を選択して頂くと、言語設定が日本語に切り替わります。設定変更後は以下の機能が利用可能です。
#
#                 </p>, <p>日本語版ウェブサイトへのクイックアクセスが可能となり、日本語の刊行物をご覧頂けます。</p>, <p>日本語版が閲覧可能な刊行物や記事については、日本語が優先表示されます。表示言語については <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/> をご参照下さい。
#                         </p>, <p>By selecting <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/>, you have now set your language to Japanese. This has several benefits, including:</p>, <p>Providing quick access to our Japan page, which collates all our Japanese content in one place.</p>, <p>Ensures that content is presented to you in Japanese first, if we have an article, publication or webpage available in Japanese. Look out for the <img alt="Japan flag" class="n-language-list__image--shadow" src="https://www.nepia.com/img/flags/flag-jp.jpg"/> indicators across the site.</p>, <p>点击选择  <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>，可将网站语言设置为中文。这能帮助您：</p>, <p>快速访问我们的中国区页面，该页面将有网站内容的中文汇总。</p>, <p>在我们的文章、出版物或者网页有中文版本提供的情况下，确保首先向您展示的是中文版本的内容。您可关注站点上的  <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>  按键。</p>, <p>By selecting <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/>, you have now set your language to Chinese. This has several benefits, including:</p>, <p>Providing quick access to our China page, which collates all our Chinese content in one place.</p>, <p>Ensures that content is presented to you in Chinese first, if we have an article, publication or webpage available in Chinese. Look out for the <img alt="China flag" src="https://www.nepia.com/img/flags/flag-ch.jpg"/> indicators across the site.</p>, <p class="n-emergency-contact-mini__text"><span class="n-emergency-contact-mini__description">Office Hours Emergencies</span> <a class="n-emergency-contact-mini__tel" href="tel: +44 191 232 5221">+44 191 232 5221</a></p>, <p class="n-staff-card__job-title"></p>, <p class="n-nav-sub-menu__text n-nav-sub-menu__text--large n-text-no-margin">Collect and reference articles, news items and contacts in your own personal space...</p>, <p class="n-actions__text"><a class="n-link" href="https://www.nepia.com/mynorth/">Find out more about MyNorth</a></p>, <p class="n-remember-me__right n-xsmall-text"><a class="n-remember-me__forgot n-link" href="https://www.nepia.com/password/reset">Forgot your password?</a></p>, <p class="n-heading-3">Access confidential risk and vessel data with NorthOnline</p>, <p class="n-north-online-description">NorthOnline is a separate area to MyNorth and requires different login credentials. If you have forgotten your password or require access to NorthOnline, please email <a href="mailto:northonline.access@nepia.com">northonline.access@nepia.com.</a></p>, <p class="n-nav-sub-menu__text">Our maritime intelligence platforms have been designed to assist you in your shipping operations. From planning a voyage, to assessing the latest Covid-19 developments, our platforms contain a wide range of regularly updated data feeds to allow you to properly manage your risks.</p>, <p class="n-nav-sub-menu__text">Our comprehensive network of correspondents are based in all the major ports and maritime centres around the globe. </p>, <p class="n-nav-sub-menu__text">From news and articles to circulars and publications, keep across the latest industry updates that are relevant to you.
# </p>, <p class="n-nav-sub-menu__text">North is a leading global marine insurer with over 160 years of history in the industry. Our purpose today remains as it was on our inception in 1860; to enable our Members to trade with confidence.</p>, <p class="n-nav-sub-menu__text">Find out more about our people and contact details for our regional offices.</p>, <p>Read our latest COVID-19 impact on shipping updates in our new online publication. You can now quickly view, print or search the countries relevant to you.</p>, <p>The below is a brief summary of information we have received so far that has the potential to impact ship operations.</p>, <p><strong>Last Updated: 05 November 2021 </strong></p>, <p>For more information on the coronavirus outbreak, visit our <a href="https://www.nepia.com/topics/covid-19-coronavirus/">Industry Expertise area</a>.</p>, <p>Our online publications are more interactive and improve searchability and speed of access. You can now read this publication directly from our website, and can simply print specific countries relevant to you. For Members, brokers and correspondents with MyNorth accounts, you can also add this publication to your library for quick access.</p>, <p>The country advice is available down the right of the publication page. You can quickly navigate to a country by clicking the heading in the contents. If you are looking for something in particular, you can use the search at the top of the publication. When you submit a search term, it will provide an overview of the results by relevancy.</p>, <p class="n-footer-logo__title">Member of</p>, <p class="n-footer-logo__title">Accreditations</p>, <p>Copyright © The North of England Protecting and Indemnity Association Limited. Registered in England. No. 505456. The Quayside, Newcastle upon Tyne, NE1 3DU Authorised by the Prudential Regulation Authority and regulated by the Financial Conduct Authority and the Prudential Regulation Authority.<br/>
# <br/>
# North's business in the EEA is underwritten by North of England P&amp;I Designated Activity Company, a wholly owned subsidiary of North incorporated in Ireland and regulated by the Central Bank of Ireland.</p>, <p>We use necessary cookies to make our website function and to enable core functionality. You can disable these in your browser settings, however sections of our website may not work correctly.</p>, <p>We also use performance cookies to help improve our website and provide the best user experience, this includes collecting and reporting information on how you use the site.</p>, <p>To get the best online experience we recommend that you accept all cookies. For more information, or to change your settings, please select ‘manage cookies’ or visit our our <a href="https://www.nepia.com/cookie-policy/">Cookie Policy</a> page.</p>]
